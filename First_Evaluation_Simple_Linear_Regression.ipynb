# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhuvan340/My-Machine-Learning-Files/blob/main/First_Evaluation_Simple_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Salary_Data.csv')

# %%
X = data['YearsExperience'].values.reshape(-1, 1)
y = data['Salary'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
plt.scatter(X, y, color='blue', label='Data Points')
plt.plot(X, regressor.predict(X), color='red', label='Regression Line')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Simple Linear Regression')
plt.legend()
plt.show()
slope = regressor.coef_[0]
intercept = regressor.intercept_
print(f'Slope of the regression line: {slope:.2f}')
print(f'Intercept of the regression line: {intercept:.2f}')
# Out:
# Slope of the regression line: 5531.35
# Intercept of the regression line: 44260.16
